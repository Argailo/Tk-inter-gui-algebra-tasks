# %% [markdown]
# # импорт библиотек и генераторов заданий

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\users\argailo\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\argailo\anaconda3\lib\site-packages (from python-docx) (4.9.3)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\argailo\anaconda3\lib\site-packages (from python-docx) (4.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from task1 import *
from task2 import *
from task3 import *
from task4 import *
from task5 import *

# %% [markdown]
# # генерация заданий в формате Latex

# %%
res1 = gen_task_1((3,2), (1,3), (1, 9))
res1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 res1 = gen_task_1((3,2), (1,3), (1, 9))
#       2 res1
#
# File ~\Documents\Ботальная имени Аргайло\Design\task1.py:29, in gen_task_1(A_size, B_size, range)
#      26 B = np.random.randint(range[0], range[1], size=B_size)  # Matrix B of size 3x3
#      28 # Matrix multiplication of B and A
# ---> 29 C = np.dot(A, B)
#      31 # Export matrices
#      32 word_A = "A="+matrix_to_word(A)+","
#
# ValueError: shapes (3,2) and (1,3) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
res2 = gen_task_2((3, 3), (1, 3), 2)
res2

# %%
res3 = gen_task_3((3, 3), (1, 5))
res3
# Out:
# ('  2x_1 + 2x_2 + x_3 = 2\n x_1 + 3x_2 + 2x_3 = 3\n 3x_1 + 3x_2 + 2x_3 = 2\n',
#  'A^{-1}= \\left(\\begin{matrix}0.0&-0.5&0.5\\\\2.0&0.5&-1.5\\\\-3.0&0.0&2.0\\\\\\end{matrix}\\right) \n',
#  'X= \\left(\\begin{matrix}-0.5 \\\\ 2.5 \\\\ -2.0\\\\\\end{matrix}\\right)')

# %%
res4 = gen_task_4((3, 3), (3, 3), (3, 3), (1, 9))
res4
# Out:
# ('\\left(\\begin{matrix}6&4&3\\\\6&8&8\\\\5&8&3\\\\\\end{matrix}\\right)∙X∙\\left(\\begin{matrix}6&1&2\\\\2&6&5\\\\2&7&7\\\\\\end{matrix}\\right)=\\left(\\begin{matrix}1&2&4\\\\7&4&7\\\\3&5&7\\\\\\end{matrix}\\right) \n',
#  'A^{-1}=\\left(\\begin{matrix}0.3125&-0.09375&-0.0625\\\\-0.17187&-0.02344&0.23437\\\\-0.0625&0.21875&-0.1875\\\\\\end{matrix}\\right)\n',
#  'B^{-1}=\\left(\\begin{matrix}0.16667&0.16667&-0.16667\\\\-0.09524&0.90476&-0.61905\\\\0.04762&-0.95238&0.80952\\\\\\end{matrix}\\right)\n',
#  'X=\\left(\\begin{matrix}-0.07515&-0.2939&0.25372\\\\0.02883&-0.02585&0.12294\\\\0.16741&0.01116&-0.06027\\\\\\end{matrix}\\right)\n')

# %%
res5 = gen_task_5((3, 3), (1, 9), 3, 3)
res5
# Out:
# ('  8x_1 + 5x_2 + 8x_3 = 2\n 4x_1 + 5x_2 + 7x_3 = 4\n 7x_1 + 2x_2 + 6x_3 = 5\n',
#  'X=C1\\left(\\begin{matrix}-0.62139 \\\\ -0.39186 \\\\ -0.67847\\\\\\end{matrix}\\right)C2\\left(\\begin{matrix}0.69434 \\\\ -0.6766 \\\\ -0.24514\\\\\\end{matrix}\\right)C3\\left(\\begin{matrix}-0.36299 \\\\ -0.62342 \\\\ 0.69252\\\\\\end{matrix}\\right)\\left(\\begin{matrix}-1.32432 \\\\ -2.75676 \\\\ 3.2973\\\\\\end{matrix}\\right)')

# %% [markdown]
# # Вывод заданий в билет. Формат - docx

# %%
from docx import Document
from docx.shared import Pt
from docx.shared import Length

# latex_formula_1 = '$\\begin{pmatrix} x_{11}&x_{12} \\\\  x_{21}&x_{22} \end{pmatrix} $'
latex_formula_1 = res1[0] + res1[1] + res1[2]
latex_formula_2 = res2[0] + res2[1]
latex_formula_3 = res3[0] + res3[1] + res3[2]
latex_formula_4 = res4[0] + res4[1] + res4[2] + res4[3]
latex_formula_5 = res5[0] + res5[1]

document = Document()

document.add_heading('Линейная алгебра, 1 семестр', level=1)

document.add_heading('1. Перемножение двух матриц', level=2)
document.add_paragraph(latex_formula_1)
document.add_heading('2. СЛАУ методом Крамера', level=2)
document.add_paragraph(latex_formula_2)
document.add_heading('3. СЛАУ методом обратной матрицы', level=2)
document.add_paragraph(latex_formula_3)
document.add_heading('4. Матричные уравнения вида AxB=C', level=2)
document.add_paragraph(latex_formula_4)
document.add_heading('5. СЛАУ методом Гаусса', level=2)
document.add_paragraph(latex_formula_5)

document.save('Линейная алгебра_1 семестр.docx')
latex_formula_1
# Out:
# 'A=\\left(\\begin{matrix}7&4\\\\8&1\\\\1&8\\\\\\end{matrix}\\right),B=\\left(\\begin{matrix}4&1&2\\\\\\end{matrix}\\right),BA=\\left(\\begin{matrix}38&33\\\\\\end{matrix}\\right)'

# %%
import tkinter as tk
class data:
    m = []
    var = 1
    c = []

d = data()
d.m = [1,2,3]
d.m
# Out:
# [1, 2, 3]

# %%
import numpy as np
import random
a = np.array
A = np.random.randint(-3, 10, (2,3)) 
A
# Out:
# array([[ 0, -2, -1],
#        [ 4,  1, -1]])
